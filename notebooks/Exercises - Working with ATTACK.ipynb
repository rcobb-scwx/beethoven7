# %% [markdown]
# # Working with MITRE's ATT&CK Framework
#
#
# # Background
#
# * ATT&CK on Github
#     * https://github.com/mitre/cti
#     * https://raw.githubusercontent.com/mitre/cti/master/enterprise-attack/enterprise-attack.json
# * STIX JSON Format
# * ATT&CK API Clients
#     * `cti-python-stix2` and `cti-taxii-client`
#     * `attack-cti`
#     * `pyattck`
#
# <hr>
#
# # Part 1 - `pyattck`
#
# ## Installation
#
# * https://pyattck.readthedocs.io/en/latest/
# * https://swimlane.com/blog/swimlane-pyattack-works-with-mitre-att-ck-framework/
#
#
#     pip install pyattck

# %%
from pyattck import Attck


attack = Attck()

# %% [markdown]
# If you're connecting through a web proxy, you should set the `HTTP_PROXY` and `HTTPS_PROXY` environment variables.

# %% [markdown]
# ## Exploring Tactics

# %%
for tactic in attack.tactics:
    print(tactic.name)
# Out:
# Collection
# Command and Control
# Credential Access
# Defense Evasion
# Discovery
# Execution
# Exfiltration
# Impact
# Initial Access
# Lateral Movement
# Persistence
# Privilege Escalation

# %% [markdown]
# The power of tab-complete in Jupyter:

# %%
example_tactic = attack.tactics[0]

# %%
example_tactic.name
# Out:
# 'Collection'

# %%
print(example_tactic.description)
# Out:
# The adversary is trying to gather data of interest to their goal.
#
# Collection consists of techniques adversaries may use to gather information and the sources information is collected from that are relevant to following through on the adversary's objectives. Frequently, the next goal after collecting data is to steal (exfiltrate) the data. Common target sources include various drive types, browsers, audio, video, and email. Common collection methods include capturing screenshots and keyboard input.

# %%
for technique in example_tactic.techniques:
    print(technique.id, technique.name)
# Out:
# T1123 Audio Capture
# T1119 Automated Collection
# T1115 Clipboard Data
# T1074 Data Staged
# T1530 Data from Cloud Storage Object
# T1213 Data from Information Repositories
# T1005 Data from Local System
# T1039 Data from Network Shared Drive
# T1025 Data from Removable Media
# T1114 Email Collection
# T1056 Input Capture
# T1185 Man in the Browser
# T1113 Screen Capture
# T1125 Video Capture

# %% [markdown]
# ## Exploring Techniques

# %%
example_technique = attack.techniques[1]

# %%
example_technique.name
# Out:
# 'Access Token Manipulation'

# %%
example_technique.id
# Out:
# 'T1134'

# %%
example_technique.description
# Out:
# "Windows uses access tokens to determine the ownership of a running process. A user can manipulate access tokens to make a running process appear as though it belongs to someone other than the user that started the process. When this occurs, the process also takes on the security context associated with the new token. For example, Microsoft promotes the use of access tokens as a security best practice. Administrators should log in as a standard user but run their tools with administrator privileges using the built-in access token manipulation command <code>runas</code>.(Citation: Microsoft runas)\n  \nAdversaries may use access tokens to operate under a different user or system security context to perform actions and evade detection. An adversary can use built-in Windows API functions to copy access tokens from existing processes; this is known as token stealing. An adversary must already be in a privileged user context (i.e. administrator) to steal a token. However, adversaries commonly use token stealing to elevate their security context from the administrator level to the SYSTEM level. An adversary can use a token to authenticate to a remote system as the account for that token if the account has appropriate permissions on the remote system.(Citation: Pentestlab Token Manipulation)\n\nAccess tokens can be leveraged by adversaries through three methods:(Citation: BlackHat Atkinson Winchester Token Manipulation)\n\n**Token Impersonation/Theft** - An adversary creates a new access token that duplicates an existing token using <code>DuplicateToken(Ex)</code>. The token can then be used with <code>ImpersonateLoggedOnUser</code> to allow the calling thread to impersonate a logged on user's security context, or with <code>SetThreadToken</code> to assign the impersonated token to a thread. This is useful for when the target user has a non-network logon session on the system.\n\n**Create Process with a Token** - An adversary creates a new access token with <code>DuplicateToken(Ex)</code> and uses it with <code>CreateProcessWithTokenW</code> to create a new process running under the security context of the impersonated user. This is useful for creating a new process under the security context of a different user.\n\n**Make and Impersonate Token** - An adversary has a username and password but the user is not logged onto the system. The adversary can then create a logon session for the user using the <code>LogonUser</code> function. The function will return a copy of the new session's access token and the adversary can use <code>SetThreadToken</code> to assign the token to a thread.\n\nAny standard user can use the <code>runas</code> command, and the Windows API functions, to create impersonation tokens; it does not require access to an administrator account.\n\nMetasploit’s Meterpreter payload allows arbitrary token manipulation and uses token impersonation to escalate privileges.(Citation: Metasploit access token) The Cobalt Strike beacon payload allows arbitrary token impersonation and can also create tokens. (Citation: Cobalt Strike Access Token)"

# %%
example_technique.wiki
# Out:
# 'https://attack.mitre.org/techniques/T1134'

# %%
for actor in example_technique.actors:
    print(actor.name)
# Out:
# Lazarus Group
# APT28
# Turla

# %%
for mitigation in example_technique.mitigations:
    print(mitigation.name)
# Out:
# Access Token Manipulation Mitigation
# Privileged Account Management
# User Account Management

# %% [markdown]
# ## Exploring Actors

# %%
for actor in attack.actors:
    print(actor.name)
# Out:
# APT1
# APT12
# APT16
# APT17
# APT18
# APT19
# APT28
# APT29
# APT3
# APT30
# APT32
# APT33
# APT34
# APT37
# APT38
# APT39
# APT41
# Axiom
# BRONZE BUTLER
# BlackOasis
# Carbanak
# Charming Kitten
# Cleaver
# Cobalt Group
# CopyKittens
# Dark Caracal
# DarkHydrus
# Darkhotel
# Deep Panda
# DragonOK
# Dragonfly
# Dragonfly 2.0
# Dust Storm
# Elderwood
# Equation
# FIN10
# FIN4
# FIN5
# FIN6
# FIN7
# FIN8
# GCMAN
# Gallmaker
# Gamaredon Group
# Gorgon Group
# Group5
# Honeybee
# Ke3chang
# Kimsuky
# Lazarus Group
# Leafminer
# Leviathan
# Lotus Blossom
# MONSOON
# Machete
# Magic Hound
# Moafee
# Molerats
# MuddyWater
# NEODYMIUM
# Naikon
# Night Dragon
# OilRig
# Orangeworm
# PLATINUM
# PROMETHIUM
# Patchwork
# PittyTiger
# Poseidon Group
# Putter Panda
# RTM
# Rancor
# Sandworm Team
# Scarlet Mimic
# Silence
# SilverTerrier
# Soft Cell
# Sowbug
# Stealth Falcon
# Stolen Pencil
# Strider
# Suckfly
# TA459
# TA505
# TEMP.Veles
# Taidoor
# The White Company
# Threat Group-1314
# Threat Group-3390
# Thrip
# Tropic Trooper
# Turla
# WIRTE
# Winnti Group
# admin@338
# menuPass

# %%
for actor in attack.actors:
    print(actor.name)
    for technique in actor.techniques:
        print('-', technique.id, technique.name)
# Out:
# APT1
# - T1003 Credential Dumping
# - T1059 Command-Line Interface
# - T1076 Remote Desktop Protocol
# - T1005 Data from Local System
# - T1002 Data Compressed
# - T1064 Scripting
# - T1057 Process Discovery
# - T1114 Email Collection
# - T1036 Masquerading
# - T1049 System Network Connections Discovery
# - T1087 Account Discovery
# - T1119 Automated Collection
# - T1075 Pass the Hash
# - T1135 Network Share Discovery
# - T1007 System Service Discovery
# - T1016 System Network Configuration Discovery
# APT12
# - T1204 User Execution
# - T1203 Exploitation for Client Execution
# - T1193 Spearphishing Attachment
# - T1102 Web Service
# APT16
# APT17
# APT18
# - T1133 External Remote Services
# - T1083 File and Directory Discovery
# - T1027 Obfuscated Files or Information
# - T1071 Standard Application Layer Protocol
# - T1078 Valid Accounts
# - T1043 Commonly Used Port
# - T1060 Registry Run Keys / Startup Folder
# - T1105 Remote File Copy
# - T1059 Command-Line Interface
# - T1053 Scheduled Task
# - T1107 File Deletion
# - T1082 System Information Discovery
# APT19
# - T1016 System Network Configuration Discovery
# - T1204 User Execution
# - T1071 Standard Application Layer Protocol
# - T1043 Commonly Used Port
# - T1132 Data Encoding
# - T1117 Regsvr32
# - T1064 Scripting
# - T1082 System Information Discovery
# - T1085 Rundll32
# - T1060 Registry Run Keys / Startup Folder
# - T1033 System Owner/User Discovery
# - T1073 DLL Side-Loading
# - T1112 Modify Registry
# - T1086 PowerShell
# - T1189 Drive-by Compromise
# - T1193 Spearphishing Attachment
# - T1031 Modify Existing Service
# - T1140 Deobfuscate/Decode Files or Information
# - T1027 Obfuscated Files or Information
# - T1143 Hidden Window
# APT28
# - T1001 Data Obfuscation
# - T1091 Replication Through Removable Media
# - T1114 Email Collection
# - T1105 Remote File Copy
# - T1173 Dynamic Data Exchange
# - T1158 Hidden Files and Directories
# - T1099 Timestomp
# - T1192 Spearphishing Link
# - T1120 Peripheral Device Discovery
# - T1113 Screen Capture
# - T1083 File and Directory Discovery
# - T1070 Indicator Removal on Host
# - T1204 User Execution
# - T1122 Component Object Model Hijacking
# - T1193 Spearphishing Attachment
# - T1213 Data from Information Repositories
# - T1037 Logon Scripts
# - T1059 Command-Line Interface
# - T1040 Network Sniffing
# - T1067 Bootkit
# - T1068 Exploitation for Privilege Escalation
# - T1211 Exploitation for Defense Evasion
# - T1119 Automated Collection
# - T1134 Access Token Manipulation
# - T1025 Data from Removable Media
# - T1074 Data Staged
# - T1075 Pass the Hash
# - T1078 Valid Accounts
# - T1199 Trusted Relationship
# - T1085 Rundll32
# - T1071 Standard Application Layer Protocol
# - T1086 PowerShell
# - T1092 Communication Through Removable Media
# - T1005 Data from Local System
# - T1003 Credential Dumping
# - T1107 File Deletion
# - T1027 Obfuscated Files or Information
# - T1014 Rootkit
# - T1002 Data Compressed
# - T1064 Scripting
# - T1090 Connection Proxy
# - T1057 Process Discovery
# - T1210 Exploitation of Remote Services
# - T1056 Input Capture
# - T1140 Deobfuscate/Decode Files or Information
# - T1203 Exploitation for Client Execution
# - T1137 Office Application Startup
# - T1221 Template Injection
# - T1024 Custom Cryptographic Protocol
# - T1043 Commonly Used Port
# - T1527 Application Access Token
# - T1528 Steal Application Access Token
# - T1143 Hidden Window
# APT29
# - T1060 Registry Run Keys / Startup Folder
# - T1064 Scripting
# - T1203 Exploitation for Client Execution
# - T1015 Accessibility Features
# - T1088 Bypass User Account Control
# - T1086 PowerShell
# - T1204 User Execution
# - T1084 Windows Management Instrumentation Event Subscription
# - T1045 Software Packing
# - T1188 Multi-hop Proxy
# - T1193 Spearphishing Attachment
# - T1047 Windows Management Instrumentation
# - T1097 Pass the Ticket
# - T1172 Domain Fronting
# - T1107 File Deletion
# - T1095 Standard Non-Application Layer Protocol
# - T1192 Spearphishing Link
# - T1085 Rundll32
# - T1027 Obfuscated Files or Information
# - T1053 Scheduled Task
# - T1043 Commonly Used Port
# - T1023 Shortcut Modification
# - T1070 Indicator Removal on Host
# APT3
# - T1074 Data Staged
# - T1087 Account Discovery
# - T1056 Input Capture
# - T1016 System Network Configuration Discovery
# - T1015 Accessibility Features
# - T1076 Remote Desktop Protocol
# - T1005 Data from Local System
# - T1108 Redundant Access
# - T1053 Scheduled Task
# - T1061 Graphical User Interface
# - T1083 File and Directory Discovery
# - T1105 Remote File Copy
# - T1090 Connection Proxy
# - T1018 Remote System Discovery
# - T1065 Uncommonly Used Port
# - T1059 Command-Line Interface
# - T1078 Valid Accounts
# - T1064 Scripting
# - T1069 Permission Groups Discovery
# - T1057 Process Discovery
# - T1003 Credential Dumping
# - T1086 PowerShell
# - T1050 New Service
# - T1104 Multi-Stage Channels
# - T1049 System Network Connections Discovery
# - T1041 Exfiltration Over Command and Control Channel
# - T1085 Rundll32
# - T1045 Software Packing
# - T1095 Standard Non-Application Layer Protocol
# - T1027 Obfuscated Files or Information
# - T1033 System Owner/User Discovery
# - T1136 Create Account
# - T1002 Data Compressed
# - T1066 Indicator Removal from Tools
# - T1043 Commonly Used Port
# - T1082 System Information Discovery
# - T1098 Account Manipulation
# - T1060 Registry Run Keys / Startup Folder
# - T1077 Windows Admin Shares
# - T1073 DLL Side-Loading
# - T1110 Brute Force
# - T1107 File Deletion
# - T1081 Credentials in Files
# - T1143 Hidden Window
# APT30
# APT32
# - T1017 Application Deployment Software
# - T1117 Regsvr32
# - T1033 System Owner/User Discovery
# - T1100 Web Shell
# - T1068 Exploitation for Privilege Escalation
# - T1086 PowerShell
# - T1075 Pass the Hash
# - T1087 Account Discovery
# - T1031 Modify Existing Service
# - T1096 NTFS File Attributes
# - T1018 Remote System Discovery
# - T1099 Timestomp
# - T1027 Obfuscated Files or Information
# - T1070 Indicator Removal on Host
# - T1009 Binary Padding
# - T1105 Remote File Copy
# - T1071 Standard Application Layer Protocol
# - T1192 Spearphishing Link
# - T1049 System Network Connections Discovery
# - T1050 New Service
# - T1053 Scheduled Task
# - T1189 Drive-by Compromise
# - T1043 Commonly Used Port
# - T1082 System Information Discovery
# - T1047 Windows Management Instrumentation
# - T1003 Credential Dumping
# - T1137 Office Application Startup
# - T1016 System Network Configuration Discovery
# - T1193 Spearphishing Attachment
# - T1216 Signed Script Proxy Execution
# - T1204 User Execution
# - T1078 Valid Accounts
# - T1036 Masquerading
# - T1064 Scripting
# - T1170 Mshta
# - T1094 Custom Command and Control Protocol
# - T1060 Registry Run Keys / Startup Folder
# - T1097 Pass the Ticket
# - T1046 Network Service Scanning
# - T1077 Windows Admin Shares
# - T1073 DLL Side-Loading
# - T1065 Uncommonly Used Port
# - T1203 Exploitation for Client Execution
# - T1041 Exfiltration Over Command and Control Channel
# - T1022 Data Encrypted
# - T1083 File and Directory Discovery
# - T1012 Query Registry
# - T1002 Data Compressed
# - T1112 Modify Registry
# - T1035 Service Execution
# - T1158 Hidden Files and Directories
# - T1107 File Deletion
# - T1222 File and Directory Permissions Modification
# - T1059 Command-Line Interface
# - T1143 Hidden Window
# APT33
# - T1192 Spearphishing Link
# - T1204 User Execution
# - T1078 Valid Accounts
# - T1203 Exploitation for Client Execution
# - T1040 Network Sniffing
# - T1003 Credential Dumping
# - T1002 Data Compressed
# - T1105 Remote File Copy
# - T1086 PowerShell
# - T1060 Registry Run Keys / Startup Folder
# - T1071 Standard Application Layer Protocol
# - T1048 Exfiltration Over Alternative Protocol
# - T1065 Uncommonly Used Port
# - T1053 Scheduled Task
# - T1132 Data Encoding
# - T1027 Obfuscated Files or Information
# - T1032 Standard Cryptographic Protocol
# - T1068 Exploitation for Privilege Escalation
# - T1043 Commonly Used Port
# - T1110 Brute Force
# - T1480 Execution Guardrails
# APT34
# APT37
# - T1203 Exploitation for Client Execution
# - T1057 Process Discovery
# - T1005 Data from Local System
# - T1204 User Execution
# - T1059 Command-Line Interface
# - T1003 Credential Dumping
# - T1082 System Information Discovery
# - T1033 System Owner/User Discovery
# - T1105 Remote File Copy
# - T1123 Audio Capture
# - T1060 Registry Run Keys / Startup Folder
# - T1106 Execution through API
# - T1094 Custom Command and Control Protocol
# - T1027 Obfuscated Files or Information
# - T1193 Spearphishing Attachment
# - T1055 Process Injection
# - T1189 Drive-by Compromise
# - T1071 Standard Application Layer Protocol
# - T1487 Disk Structure Wipe
# - T1102 Web Service
# - T1043 Commonly Used Port
# - T1064 Scripting
# - T1116 Code Signing
# - T1173 Dynamic Data Exchange
# - T1120 Peripheral Device Discovery
# - T1088 Bypass User Account Control
# - T1529 System Shutdown/Reboot
# APT38
# - T1071 Standard Application Layer Protocol
# - T1056 Input Capture
# - T1057 Process Discovery
# - T1112 Modify Registry
# - T1189 Drive-by Compromise
# - T1115 Clipboard Data
# - T1045 Software Packing
# - T1059 Command-Line Interface
# - T1105 Remote File Copy
# - T1107 File Deletion
# - T1070 Indicator Removal on Host
# - T1494 Runtime Data Manipulation
# - T1493 Transmitted Data Manipulation
# - T1492 Stored Data Manipulation
# - T1487 Disk Structure Wipe
# - T1486 Data Encrypted for Impact
# - T1485 Data Destruction
# - T1049 System Network Connections Discovery
# - T1529 System Shutdown/Reboot
# APT39
# - T1193 Spearphishing Attachment
# - T1192 Spearphishing Link
# - T1076 Remote Desktop Protocol
# - T1060 Registry Run Keys / Startup Folder
# - T1053 Scheduled Task
# - T1023 Shortcut Modification
# - T1016 System Network Configuration Discovery
# - T1002 Data Compressed
# - T1090 Connection Proxy
# - T1003 Credential Dumping
# - T1064 Scripting
# - T1078 Valid Accounts
# - T1046 Network Service Scanning
# - T1021 Remote Services
# - T1100 Web Shell
# - T1204 User Execution
# - T1045 Software Packing
# - T1033 System Owner/User Discovery
# APT41
# - T1116 Code Signing
# - T1014 Rootkit
# - T1067 Bootkit
# - T1110 Brute Force
# - T1046 Network Service Scanning
# - T1076 Remote Desktop Protocol
# - T1003 Credential Dumping
# - T1015 Accessibility Features
# - T1086 PowerShell
# - T1036 Masquerading
# - T1193 Spearphishing Attachment
# - T1133 External Remote Services
# - T1090 Connection Proxy
# - T1483 Domain Generation Algorithms
# - T1195 Supply Chain Compromise
# - T1056 Input Capture
# - T1078 Valid Accounts
# - T1047 Windows Management Instrumentation
# - T1033 System Owner/User Discovery
# - T1060 Registry Run Keys / Startup Folder
# - T1070 Indicator Removal on Host
# - T1112 Modify Registry
# - T1002 Data Compressed
# - T1496 Resource Hijacking
# - T1486 Data Encrypted for Impact
# - T1146 Clear Command History
# - T1102 Web Service
# - T1031 Modify Existing Service
# - T1053 Scheduled Task
# - T1059 Command-Line Interface
# - T1136 Create Account
# - T1016 System Network Configuration Discovery
# - T1071 Standard Application Layer Protocol
# - T1055 Process Injection
# - T1008 Fallback Channels
# - T1223 Compiled HTML File
# - T1107 File Deletion
# - T1073 DLL Side-Loading
# - T1203 Exploitation for Client Execution
# - T1049 System Network Connections Discovery
# - T1135 Network Share Discovery
# Axiom
# - T1001 Data Obfuscation
# - T1003 Credential Dumping
# - T1190 Exploit Public-Facing Application
# - T1015 Accessibility Features
# - T1076 Remote Desktop Protocol
# BRONZE BUTLER
# - T1002 Data Compressed
# - T1204 User Execution
# - T1088 Bypass User Account Control
# - T1053 Scheduled Task
# - T1036 Masquerading
# - T1102 Web Service
# - T1083 File and Directory Discovery
# - T1113 Screen Capture
# - T1071 Standard Application Layer Protocol
# - T1189 Drive-by Compromise
# - T1003 Credential Dumping
# - T1140 Deobfuscate/Decode Files or Information
# - T1087 Account Discovery
# - T1032 Standard Cryptographic Protocol
# - T1107 File Deletion
# - T1018 Remote System Discovery
# - T1005 Data from Local System
# - T1124 System Time Discovery
# - T1064 Scripting
# - T1203 Exploitation for Client Execution
# - T1105 Remote File Copy
# - T1060 Registry Run Keys / Startup Folder
# - T1024 Custom Cryptographic Protocol
# - T1022 Data Encrypted
# - T1009 Binary Padding
# - T1097 Pass the Ticket
# - T1193 Spearphishing Attachment
# - T1132 Data Encoding
# - T1039 Data from Network Shared Drive
# - T1086 PowerShell
# - T1059 Command-Line Interface
# BlackOasis
# - T1027 Obfuscated Files or Information
# Carbanak
# - T1036 Masquerading
# - T1078 Valid Accounts
# - T1050 New Service
# - T1102 Web Service
# - T1085 Rundll32
# - T1089 Disabling Security Tools
# - T1219 Remote Access Tools
# Charming Kitten
# Cleaver
# - T1003 Credential Dumping
# Cobalt Group
# - T1076 Remote Desktop Protocol
# - T1191 CMSTP
# - T1108 Redundant Access
# - T1071 Standard Application Layer Protocol
# - T1053 Scheduled Task
# - T1204 User Execution
# - T1192 Spearphishing Link
# - T1046 Network Service Scanning
# - T1050 New Service
# - T1105 Remote File Copy
# - T1088 Bypass User Account Control
# - T1027 Obfuscated Files or Information
# - T1068 Exploitation for Privilege Escalation
# - T1193 Spearphishing Attachment
# - T1055 Process Injection
# - T1117 Regsvr32
# - T1107 File Deletion
# - T1173 Dynamic Data Exchange
# - T1219 Remote Access Tools
# - T1060 Registry Run Keys / Startup Folder
# - T1203 Exploitation for Client Execution
# - T1037 Logon Scripts
# - T1032 Standard Cryptographic Protocol
# - T1063 Security Software Discovery
# - T1064 Scripting
# - T1220 XSL Script Processing
# - T1086 PowerShell
# - T1059 Command-Line Interface
# - T1218 Signed Binary Proxy Execution
# CopyKittens
# - T1085 Rundll32
# - T1002 Data Compressed
# - T1086 PowerShell
# - T1022 Data Encrypted
# - T1116 Code Signing
# - T1143 Hidden Window
# Dark Caracal
# - T1064 Scripting
# - T1204 User Execution
# - T1194 Spearphishing via Service
# - T1005 Data from Local System
# - T1083 File and Directory Discovery
# - T1189 Drive-by Compromise
# - T1223 Compiled HTML File
# - T1060 Registry Run Keys / Startup Folder
# - T1113 Screen Capture
# - T1045 Software Packing
# - T1071 Standard Application Layer Protocol
# - T1027 Obfuscated Files or Information
# DarkHydrus
# - T1187 Forced Authentication
# - T1193 Spearphishing Attachment
# - T1221 Template Injection
# - T1204 User Execution
# - T1086 PowerShell
# - T1143 Hidden Window
# Darkhotel
# - T1091 Replication Through Removable Media
# - T1116 Code Signing
# - T1080 Taint Shared Content
# - T1016 System Network Configuration Discovery
# - T1204 User Execution
# - T1056 Input Capture
# - T1027 Obfuscated Files or Information
# - T1189 Drive-by Compromise
# - T1064 Scripting
# - T1057 Process Discovery
# - T1193 Spearphishing Attachment
# - T1140 Deobfuscate/Decode Files or Information
# - T1063 Security Software Discovery
# - T1082 System Information Discovery
# - T1023 Shortcut Modification
# - T1060 Registry Run Keys / Startup Folder
# Deep Panda
# - T1117 Regsvr32
# - T1047 Windows Management Instrumentation
# - T1066 Indicator Removal from Tools
# - T1077 Windows Admin Shares
# - T1018 Remote System Discovery
# - T1064 Scripting
# - T1057 Process Discovery
# - T1015 Accessibility Features
# - T1086 PowerShell
# - T1100 Web Shell
# - T1143 Hidden Window
# DragonOK
# Dragonfly
# Dragonfly 2.0
# - T1036 Masquerading
# - T1069 Permission Groups Discovery
# - T1204 User Execution
# - T1059 Command-Line Interface
# - T1071 Standard Application Layer Protocol
# - T1136 Create Account
# - T1089 Disabling Security Tools
# - T1112 Modify Registry
# - T1221 Template Injection
# - T1114 Email Collection
# - T1189 Drive-by Compromise
# - T1003 Credential Dumping
# - T1018 Remote System Discovery
# - T1070 Indicator Removal on Host
# - T1053 Scheduled Task
# - T1083 File and Directory Discovery
# - T1135 Network Share Discovery
# - T1078 Valid Accounts
# - T1005 Data from Local System
# - T1012 Query Registry
# - T1187 Forced Authentication
# - T1064 Scripting
# - T1113 Screen Capture
# - T1016 System Network Configuration Discovery
# - T1107 File Deletion
# - T1105 Remote File Copy
# - T1023 Shortcut Modification
# - T1100 Web Shell
# - T1193 Spearphishing Attachment
# - T1110 Brute Force
# - T1192 Spearphishing Link
# - T1133 External Remote Services
# - T1060 Registry Run Keys / Startup Folder
# - T1076 Remote Desktop Protocol
# - T1086 PowerShell
# - T1033 System Owner/User Discovery
# - T1074 Data Staged
# - T1098 Account Manipulation
# - T1043 Commonly Used Port
# - T1087 Account Discovery
# - T1002 Data Compressed
# Dust Storm
# - T1027 Obfuscated Files or Information
# - T1005 Data from Local System
# - T1083 File and Directory Discovery
# Elderwood
# - T1045 Software Packing
# - T1195 Supply Chain Compromise
# - T1189 Drive-by Compromise
# - T1192 Spearphishing Link
# - T1027 Obfuscated Files or Information
# - T1203 Exploitation for Client Execution
# - T1193 Spearphishing Attachment
# - T1204 User Execution
# - T1105 Remote File Copy
# Equation
# - T1109 Component Firmware
# - T1480 Execution Guardrails
# - T1120 Peripheral Device Discovery
# FIN10
# - T1086 PowerShell
# - T1064 Scripting
# - T1107 File Deletion
# - T1033 System Owner/User Discovery
# - T1060 Registry Run Keys / Startup Folder
# - T1053 Scheduled Task
# - T1078 Valid Accounts
# - T1076 Remote Desktop Protocol
# - T1105 Remote File Copy
# FIN4
# - T1204 User Execution
# - T1141 Input Prompt
# - T1078 Valid Accounts
# - T1188 Multi-hop Proxy
# - T1114 Email Collection
# - T1193 Spearphishing Attachment
# - T1071 Standard Application Layer Protocol
# - T1192 Spearphishing Link
# - T1056 Input Capture
# - T1064 Scripting
# - T1492 Stored Data Manipulation
# FIN5
# - T1108 Redundant Access
# - T1107 File Deletion
# - T1018 Remote System Discovery
# - T1070 Indicator Removal on Host
# - T1078 Valid Accounts
# - T1003 Credential Dumping
# - T1074 Data Staged
# - T1064 Scripting
# - T1133 External Remote Services
# - T1119 Automated Collection
# FIN6
# - T1087 Account Discovery
# - T1018 Remote System Discovery
# - T1053 Scheduled Task
# - T1022 Data Encrypted
# - T1076 Remote Desktop Protocol
# - T1119 Automated Collection
# - T1002 Data Compressed
# - T1068 Exploitation for Privilege Escalation
# - T1086 PowerShell
# - T1046 Network Service Scanning
# - T1064 Scripting
# - T1060 Registry Run Keys / Startup Folder
# - T1074 Data Staged
# - T1078 Valid Accounts
# - T1003 Credential Dumping
# - T1071 Standard Application Layer Protocol
# - T1032 Standard Cryptographic Protocol
# - T1036 Masquerading
# - T1102 Web Service
# - T1069 Permission Groups Discovery
# - T1035 Service Execution
# - T1116 Code Signing
# - T1047 Windows Management Instrumentation
# - T1194 Spearphishing via Service
# FIN7
# - T1125 Video Capture
# - T1116 Code Signing
# - T1036 Masquerading
# - T1023 Shortcut Modification
# - T1138 Application Shimming
# - T1204 User Execution
# - T1086 PowerShell
# - T1071 Standard Application Layer Protocol
# - T1173 Dynamic Data Exchange
# - T1170 Mshta
# - T1059 Command-Line Interface
# - T1102 Web Service
# - T1193 Spearphishing Attachment
# - T1050 New Service
# - T1105 Remote File Copy
# - T1043 Commonly Used Port
# - T1053 Scheduled Task
# - T1064 Scripting
# - T1027 Obfuscated Files or Information
# - T1113 Screen Capture
# - T1060 Registry Run Keys / Startup Folder
# - T1497 Virtualization/Sandbox Evasion
# FIN8
# - T1027 Obfuscated Files or Information
# - T1193 Spearphishing Attachment
# - T1043 Commonly Used Port
# - T1078 Valid Accounts
# - T1002 Data Compressed
# - T1105 Remote File Copy
# - T1204 User Execution
# - T1064 Scripting
# - T1076 Remote Desktop Protocol
# - T1059 Command-Line Interface
# - T1107 File Deletion
# - T1070 Indicator Removal on Host
# - T1047 Windows Management Instrumentation
# - T1003 Credential Dumping
# - T1018 Remote System Discovery
# - T1048 Exfiltration Over Alternative Protocol
# - T1053 Scheduled Task
# - T1032 Standard Cryptographic Protocol
# - T1077 Windows Admin Shares
# - T1068 Exploitation for Privilege Escalation
# - T1086 PowerShell
# - T1074 Data Staged
# - T1063 Security Software Discovery
# - T1112 Modify Registry
# - T1192 Spearphishing Link
# GCMAN
# - T1021 Remote Services
# Gallmaker
# - T1193 Spearphishing Attachment
# - T1204 User Execution
# - T1027 Obfuscated Files or Information
# - T1064 Scripting
# - T1173 Dynamic Data Exchange
# - T1086 PowerShell
# - T1002 Data Compressed
# Gamaredon Group
# - T1041 Exfiltration Over Command and Control Channel
# - T1082 System Information Discovery
# - T1071 Standard Application Layer Protocol
# - T1120 Peripheral Device Discovery
# - T1105 Remote File Copy
# - T1033 System Owner/User Discovery
# - T1025 Data from Removable Media
# - T1064 Scripting
# Gorgon Group
# - T1193 Spearphishing Attachment
# - T1089 Disabling Security Tools
# - T1055 Process Injection
# - T1023 Shortcut Modification
# - T1059 Command-Line Interface
# - T1106 Execution through API
# - T1105 Remote File Copy
# - T1065 Uncommonly Used Port
# - T1204 User Execution
# - T1140 Deobfuscate/Decode Files or Information
# - T1093 Process Hollowing
# - T1060 Registry Run Keys / Startup Folder
# - T1086 PowerShell
# - T1112 Modify Registry
# - T1064 Scripting
# - T1143 Hidden Window
# Group5
# - T1065 Uncommonly Used Port
# - T1107 File Deletion
# - T1113 Screen Capture
# - T1027 Obfuscated Files or Information
# - T1056 Input Capture
# - T1045 Software Packing
# Honeybee
# - T1088 Bypass User Account Control
# - T1182 AppCert DLLs
# - T1107 File Deletion
# - T1002 Data Compressed
# - T1057 Process Discovery
# - T1082 System Information Discovery
# - T1031 Modify Existing Service
# - T1074 Data Staged
# - T1083 File and Directory Discovery
# - T1140 Deobfuscate/Decode Files or Information
# - T1022 Data Encrypted
# - T1064 Scripting
# - T1027 Obfuscated Files or Information
# - T1060 Registry Run Keys / Startup Folder
# - T1112 Modify Registry
# - T1055 Process Injection
# - T1005 Data from Local System
# - T1116 Code Signing
# - T1035 Service Execution
# - T1071 Standard Application Layer Protocol
# - T1020 Automated Exfiltration
# - T1059 Command-Line Interface
# Ke3chang
# - T1005 Data from Local System
# - T1007 System Service Discovery
# - T1022 Data Encrypted
# - T1082 System Information Discovery
# - T1069 Permission Groups Discovery
# - T1087 Account Discovery
# - T1114 Email Collection
# - T1018 Remote System Discovery
# - T1016 System Network Configuration Discovery
# - T1003 Credential Dumping
# - T1059 Command-Line Interface
# - T1097 Pass the Ticket
# - T1077 Windows Admin Shares
# - T1083 File and Directory Discovery
# - T1050 New Service
# - T1133 External Remote Services
# - T1213 Data from Information Repositories
# - T1060 Registry Run Keys / Startup Folder
# - T1057 Process Discovery
# - T1041 Exfiltration Over Command and Control Channel
# - T1049 System Network Connections Discovery
# - T1064 Scripting
# - T1071 Standard Application Layer Protocol
# - T1056 Input Capture
# - T1002 Data Compressed
# - T1035 Service Execution
# - T1036 Masquerading
# Kimsuky
# - T1193 Spearphishing Attachment
# - T1042 Change Default File Association
# - T1170 Mshta
# - T1056 Input Capture
# - T1219 Remote Access Tools
# - T1176 Browser Extensions
# - T1005 Data from Local System
# - T1081 Credentials in Files
# - T1086 PowerShell
# - T1083 File and Directory Discovery
# - T1107 File Deletion
# - T1060 Registry Run Keys / Startup Folder
# - T1022 Data Encrypted
# - T1055 Process Injection
# - T1089 Disabling Security Tools
# - T1082 System Information Discovery
# - T1050 New Service
# - T1041 Exfiltration Over Command and Control Channel
# - T1192 Spearphishing Link
# Lazarus Group
# - T1134 Access Token Manipulation
# - T1098 Account Manipulation
# - T1189 Drive-by Compromise
# - T1158 Hidden Files and Directories
# - T1055 Process Injection
# - T1223 Compiled HTML File
# - T1064 Scripting
# - T1067 Bootkit
# - T1076 Remote Desktop Protocol
# - T1107 File Deletion
# - T1060 Registry Run Keys / Startup Folder
# - T1193 Spearphishing Attachment
# - T1074 Data Staged
# - T1132 Data Encoding
# - T1056 Input Capture
# - T1043 Commonly Used Port
# - T1041 Exfiltration Over Command and Control Channel
# - T1027 Obfuscated Files or Information
# - T1083 File and Directory Discovery
# - T1033 System Owner/User Discovery
# - T1089 Disabling Security Tools
# - T1099 Timestomp
# - T1071 Standard Application Layer Protocol
# - T1124 System Time Discovery
# - T1005 Data from Local System
# - T1023 Shortcut Modification
# - T1010 Application Window Discovery
# - T1024 Custom Cryptographic Protocol
# - T1003 Credential Dumping
# - T1203 Exploitation for Client Execution
# - T1016 System Network Configuration Discovery
# - T1050 New Service
# - T1012 Query Registry
# - T1047 Windows Management Instrumentation
# - T1057 Process Discovery
# - T1105 Remote File Copy
# - T1022 Data Encrypted
# - T1090 Connection Proxy
# - T1077 Windows Admin Shares
# - T1008 Fallback Channels
# - T1110 Brute Force
# - T1204 User Execution
# - T1065 Uncommonly Used Port
# - T1026 Multiband Communication
# - T1002 Data Compressed
# - T1032 Standard Cryptographic Protocol
# - T1082 System Information Discovery
# - T1059 Command-Line Interface
# - T1048 Exfiltration Over Alternative Protocol
# - T1489 Service Stop
# - T1487 Disk Structure Wipe
# - T1488 Disk Content Wipe
# - T1485 Data Destruction
# - T1496 Resource Hijacking
# - T1529 System Shutdown/Reboot
# Leafminer
# - T1046 Network Service Scanning
# - T1110 Brute Force
# - T1003 Credential Dumping
# - T1136 Create Account
# - T1083 File and Directory Discovery
# - T1189 Drive-by Compromise
# - T1027 Obfuscated Files or Information
# - T1108 Redundant Access
# - T1114 Email Collection
# - T1064 Scripting
# - T1018 Remote System Discovery
# Leviathan
# - T1059 Command-Line Interface
# - T1197 BITS Jobs
# - T1117 Regsvr32
# - T1064 Scripting
# - T1140 Deobfuscate/Decode Files or Information
# - T1203 Exploitation for Client Execution
# - T1027 Obfuscated Files or Information
# - T1074 Data Staged
# - T1086 PowerShell
# - T1078 Valid Accounts
# - T1060 Registry Run Keys / Startup Folder
# - T1105 Remote File Copy
# - T1047 Windows Management Instrumentation
# - T1023 Shortcut Modification
# - T1102 Web Service
# - T1084 Windows Management Instrumentation Event Subscription
# - T1193 Spearphishing Attachment
# - T1192 Spearphishing Link
# - T1009 Binary Padding
# - T1204 User Execution
# - T1116 Code Signing
# - T1021 Remote Services
# - T1003 Credential Dumping
# - T1076 Remote Desktop Protocol
# - T1100 Web Shell
# Lotus Blossom
# MONSOON
# Machete
# - T1193 Spearphishing Attachment
# - T1192 Spearphishing Link
# - T1064 Scripting
# - T1043 Commonly Used Port
# - T1027 Obfuscated Files or Information
# - T1071 Standard Application Layer Protocol
# - T1060 Registry Run Keys / Startup Folder
# - T1074 Data Staged
# - T1025 Data from Removable Media
# - T1053 Scheduled Task
# - T1032 Standard Cryptographic Protocol
# - T1204 User Execution
# Magic Hound
# - T1043 Commonly Used Port
# - T1083 File and Directory Discovery
# - T1105 Remote File Copy
# - T1064 Scripting
# - T1114 Email Collection
# - T1059 Command-Line Interface
# - T1033 System Owner/User Discovery
# - T1016 System Network Configuration Discovery
# - T1027 Obfuscated Files or Information
# - T1193 Spearphishing Attachment
# - T1082 System Information Discovery
# - T1065 Uncommonly Used Port
# - T1002 Data Compressed
# - T1194 Spearphishing via Service
# - T1060 Registry Run Keys / Startup Folder
# - T1086 PowerShell
# - T1107 File Deletion
# - T1204 User Execution
# - T1057 Process Discovery
# - T1192 Spearphishing Link
# - T1102 Web Service
# - T1071 Standard Application Layer Protocol
# - T1056 Input Capture
# - T1003 Credential Dumping
# - T1113 Screen Capture
# - T1143 Hidden Window
# - T1098 Account Manipulation
# Moafee
# - T1009 Binary Padding
# Molerats
# - T1003 Credential Dumping
# - T1057 Process Discovery
# - T1116 Code Signing
# MuddyWater
# - T1036 Masquerading
# - T1060 Registry Run Keys / Startup Folder
# - T1193 Spearphishing Attachment
# - T1064 Scripting
# - T1003 Credential Dumping
# - T1033 System Owner/User Discovery
# - T1047 Windows Management Instrumentation
# - T1113 Screen Capture
# - T1088 Bypass User Account Control
# - T1140 Deobfuscate/Decode Files or Information
# - T1027 Obfuscated Files or Information
# - T1085 Rundll32
# - T1191 CMSTP
# - T1204 User Execution
# - T1173 Dynamic Data Exchange
# - T1063 Security Software Discovery
# - T1059 Command-Line Interface
# - T1105 Remote File Copy
# - T1090 Connection Proxy
# - T1057 Process Discovery
# - T1002 Data Compressed
# - T1081 Credentials in Files
# - T1175 Component Object Model and Distributed COM
# - T1170 Mshta
# - T1082 System Information Discovery
# - T1086 PowerShell
# - T1083 File and Directory Discovery
# - T1016 System Network Configuration Discovery
# - T1500 Compile After Delivery
# - T1104 Multi-Stage Channels
# - T1503 Credentials from Web Browsers
# NEODYMIUM
# Naikon
# - T1016 System Network Configuration Discovery
# - T1063 Security Software Discovery
# Night Dragon
# - T1003 Credential Dumping
# - T1190 Exploit Public-Facing Application
# - T1089 Disabling Security Tools
# - T1192 Spearphishing Link
# - T1071 Standard Application Layer Protocol
# - T1078 Valid Accounts
# - T1043 Commonly Used Port
# - T1027 Obfuscated Files or Information
# - T1075 Pass the Hash
# - T1219 Remote Access Tools
# - T1204 User Execution
# - T1133 External Remote Services
# - T1045 Software Packing
# - T1074 Data Staged
# OilRig
# - T1057 Process Discovery
# - T1140 Deobfuscate/Decode Files or Information
# - T1094 Custom Command and Control Protocol
# - T1119 Automated Collection
# - T1107 File Deletion
# - T1108 Redundant Access
# - T1113 Screen Capture
# - T1021 Remote Services
# - T1069 Permission Groups Discovery
# - T1046 Network Service Scanning
# - T1064 Scripting
# - T1133 External Remote Services
# - T1076 Remote Desktop Protocol
# - T1047 Windows Management Instrumentation
# - T1053 Scheduled Task
# - T1049 System Network Connections Discovery
# - T1007 System Service Discovery
# - T1016 System Network Configuration Discovery
# - T1012 Query Registry
# - T1056 Input Capture
# - T1059 Command-Line Interface
# - T1082 System Information Discovery
# - T1087 Account Discovery
# - T1110 Brute Force
# - T1048 Exfiltration Over Alternative Protocol
# - T1193 Spearphishing Attachment
# - T1204 User Execution
# - T1027 Obfuscated Files or Information
# - T1086 PowerShell
# - T1071 Standard Application Layer Protocol
# - T1100 Web Shell
# - T1066 Indicator Removal from Tools
# - T1033 System Owner/User Discovery
# - T1003 Credential Dumping
# - T1192 Spearphishing Link
# - T1008 Fallback Channels
# - T1201 Password Policy Discovery
# - T1223 Compiled HTML File
# - T1078 Valid Accounts
# - T1105 Remote File Copy
# - T1032 Standard Cryptographic Protocol
# - T1081 Credentials in Files
# - T1043 Commonly Used Port
# - T1194 Spearphishing via Service
# Orangeworm
# - T1077 Windows Admin Shares
# - T1071 Standard Application Layer Protocol
# PLATINUM
# - T1068 Exploitation for Privilege Escalation
# - T1095 Standard Non-Application Layer Protocol
# - T1094 Custom Command and Control Protocol
# - T1003 Credential Dumping
# - T1105 Remote File Copy
# - T1055 Process Injection
# - T1189 Drive-by Compromise
# - T1056 Input Capture
# - T1193 Spearphishing Attachment
# - T1204 User Execution
# - T1179 Hooking
# - T1036 Masquerading
# PROMETHIUM
# Patchwork
# - T1083 File and Directory Discovery
# - T1082 System Information Discovery
# - T1093 Process Hollowing
# - T1173 Dynamic Data Exchange
# - T1022 Data Encrypted
# - T1105 Remote File Copy
# - T1203 Exploitation for Client Execution
# - T1107 File Deletion
# - T1063 Security Software Discovery
# - T1003 Credential Dumping
# - T1027 Obfuscated Files or Information
# - T1053 Scheduled Task
# - T1073 DLL Side-Loading
# - T1119 Automated Collection
# - T1060 Registry Run Keys / Startup Folder
# - T1009 Binary Padding
# - T1189 Drive-by Compromise
# - T1088 Bypass User Account Control
# - T1086 PowerShell
# - T1066 Indicator Removal from Tools
# - T1045 Software Packing
# - T1193 Spearphishing Attachment
# - T1074 Data Staged
# - T1033 System Owner/User Discovery
# - T1204 User Execution
# - T1132 Data Encoding
# - T1192 Spearphishing Link
# - T1112 Modify Registry
# - T1036 Masquerading
# - T1005 Data from Local System
# - T1064 Scripting
# - T1076 Remote Desktop Protocol
# - T1102 Web Service
# - T1059 Command-Line Interface
# PittyTiger
# - T1078 Valid Accounts
# Poseidon Group
# - T1049 System Network Connections Discovery
# - T1036 Masquerading
# - T1086 PowerShell
# - T1007 System Service Discovery
# - T1057 Process Discovery
# - T1003 Credential Dumping
# - T1087 Account Discovery
# Putter Panda
# - T1089 Disabling Security Tools
# - T1060 Registry Run Keys / Startup Folder
# - T1055 Process Injection
# - T1027 Obfuscated Files or Information
# RTM
# - T1102 Web Service
# Rancor
# - T1193 Spearphishing Attachment
# - T1053 Scheduled Task
# - T1105 Remote File Copy
# - T1071 Standard Application Layer Protocol
# - T1059 Command-Line Interface
# - T1064 Scripting
# - T1204 User Execution
# - T1218 Signed Binary Proxy Execution
# Sandworm Team
# Scarlet Mimic
# - T1036 Masquerading
# Silence
# - T1125 Video Capture
# - T1113 Screen Capture
# - T1107 File Deletion
# - T1027 Obfuscated Files or Information
# - T1106 Execution through API
# - T1223 Compiled HTML File
# - T1204 User Execution
# - T1059 Command-Line Interface
# - T1035 Service Execution
# - T1064 Scripting
# - T1053 Scheduled Task
# - T1193 Spearphishing Attachment
# SilverTerrier
# - T1071 Standard Application Layer Protocol
# Soft Cell
# - T1190 Exploit Public-Facing Application
# - T1073 DLL Side-Loading
# - T1078 Valid Accounts
# - T1136 Create Account
# - T1100 Web Shell
# - T1086 PowerShell
# - T1047 Windows Management Instrumentation
# - T1059 Command-Line Interface
# - T1214 Credentials in Registry
# - T1003 Credential Dumping
# - T1016 System Network Configuration Discovery
# - T1049 System Network Connections Discovery
# - T1033 System Owner/User Discovery
# - T1105 Remote File Copy
# - T1036 Masquerading
# - T1053 Scheduled Task
# - T1045 Software Packing
# - T1090 Connection Proxy
# - T1027 Obfuscated Files or Information
# - T1074 Data Staged
# - T1022 Data Encrypted
# - T1002 Data Compressed
# - T1133 External Remote Services
# - T1018 Remote System Discovery
# - T1005 Data from Local System
# - T1075 Pass the Hash
# - T1066 Indicator Removal from Tools
# - T1041 Exfiltration Over Command and Control Channel
# Sowbug
# - T1003 Credential Dumping
# - T1083 File and Directory Discovery
# - T1056 Input Capture
# - T1002 Data Compressed
# - T1135 Network Share Discovery
# - T1059 Command-Line Interface
# - T1039 Data from Network Shared Drive
# - T1082 System Information Discovery
# - T1036 Masquerading
# Stealth Falcon
# - T1005 Data from Local System
# - T1064 Scripting
# - T1033 System Owner/User Discovery
# - T1082 System Information Discovery
# - T1041 Exfiltration Over Command and Control Channel
# - T1071 Standard Application Layer Protocol
# - T1003 Credential Dumping
# - T1086 PowerShell
# - T1032 Standard Cryptographic Protocol
# - T1047 Windows Management Instrumentation
# - T1053 Scheduled Task
# - T1057 Process Discovery
# - T1016 System Network Configuration Discovery
# - T1012 Query Registry
# Stolen Pencil
# - T1003 Credential Dumping
# - T1040 Network Sniffing
# - T1078 Valid Accounts
# - T1056 Input Capture
# - T1076 Remote Desktop Protocol
# - T1176 Browser Extensions
# - T1192 Spearphishing Link
# - T1081 Credentials in Files
# - T1108 Redundant Access
# - T1503 Credentials from Web Browsers
# Strider
# - T1090 Connection Proxy
# - T1003 Credential Dumping
# Suckfly
# - T1046 Network Service Scanning
# - T1078 Valid Accounts
# - T1059 Command-Line Interface
# - T1003 Credential Dumping
# - T1116 Code Signing
# TA459
# - T1193 Spearphishing Attachment
# - T1203 Exploitation for Client Execution
# - T1204 User Execution
# - T1064 Scripting
# - T1086 PowerShell
# TA505
# - T1193 Spearphishing Attachment
# - T1173 Dynamic Data Exchange
# - T1192 Spearphishing Link
# - T1086 PowerShell
# - T1064 Scripting
# - T1486 Data Encrypted for Impact
# - T1081 Credentials in Files
# - T1027 Obfuscated Files or Information
# - T1204 User Execution
# - T1218 Signed Binary Proxy Execution
# - T1085 Rundll32
# - T1116 Code Signing
# - T1105 Remote File Copy
# - T1503 Credentials from Web Browsers
# TEMP.Veles
# - T1036 Masquerading
# - T1003 Credential Dumping
# - T1183 Image File Execution Options Injection
# - T1053 Scheduled Task
# - T1099 Timestomp
# - T1107 File Deletion
# - T1074 Data Staged
# - T1021 Remote Services
# - T1078 Valid Accounts
# - T1076 Remote Desktop Protocol
# - T1133 External Remote Services
# - T1100 Web Shell
# - T1065 Uncommonly Used Port
# - T1043 Commonly Used Port
# - T1086 PowerShell
# - T1066 Indicator Removal from Tools
# Taidoor
# - T1032 Standard Cryptographic Protocol
# The White Company
# - T1124 System Time Discovery
# - T1063 Security Software Discovery
# - T1107 File Deletion
# - T1497 Virtualization/Sandbox Evasion
# - T1203 Exploitation for Client Execution
# - T1045 Software Packing
# - T1204 User Execution
# - T1193 Spearphishing Attachment
# Threat Group-1314
# - T1059 Command-Line Interface
# - T1077 Windows Admin Shares
# - T1078 Valid Accounts
# - T1072 Third-party Software
# Threat Group-3390
# - T1018 Remote System Discovery
# - T1087 Account Discovery
# - T1105 Remote File Copy
# - T1022 Data Encrypted
# - T1108 Redundant Access
# - T1038 DLL Search Order Hijacking
# - T1071 Standard Application Layer Protocol
# - T1086 PowerShell
# - T1073 DLL Side-Loading
# - T1055 Process Injection
# - T1049 System Network Connections Discovery
# - T1133 External Remote Services
# - T1027 Obfuscated Files or Information
# - T1088 Bypass User Account Control
# - T1028 Windows Remote Management
# - T1068 Exploitation for Privilege Escalation
# - T1030 Data Transfer Size Limits
# - T1047 Windows Management Instrumentation
# - T1002 Data Compressed
# - T1107 File Deletion
# - T1003 Credential Dumping
# - T1126 Network Share Connection Removal
# - T1016 System Network Configuration Discovery
# - T1043 Commonly Used Port
# - T1059 Command-Line Interface
# - T1112 Modify Registry
# - T1189 Drive-by Compromise
# - T1078 Valid Accounts
# - T1005 Data from Local System
# - T1074 Data Staged
# - T1056 Input Capture
# - T1119 Automated Collection
# - T1089 Disabling Security Tools
# - T1053 Scheduled Task
# - T1060 Registry Run Keys / Startup Folder
# - T1140 Deobfuscate/Decode Files or Information
# - T1012 Query Registry
# - T1050 New Service
# - T1046 Network Service Scanning
# - T1100 Web Shell
# - T1210 Exploitation of Remote Services
# - T1203 Exploitation for Client Execution
# Thrip
# - T1219 Remote Access Tools
# - T1086 PowerShell
# - T1048 Exfiltration Over Alternative Protocol
# Tropic Trooper
# - T1158 Hidden Files and Directories
# - T1043 Commonly Used Port
# - T1140 Deobfuscate/Decode Files or Information
# - T1055 Process Injection
# - T1057 Process Discovery
# - T1004 Winlogon Helper DLL
# - T1203 Exploitation for Client Execution
# - T1193 Spearphishing Attachment
# - T1063 Security Software Discovery
# - T1027 Obfuscated Files or Information
# - T1032 Standard Cryptographic Protocol
# - T1221 Template Injection
# - T1073 DLL Side-Loading
# - T1046 Network Service Scanning
# - T1135 Network Share Discovery
# - T1082 System Information Discovery
# - T1033 System Owner/User Discovery
# - T1050 New Service
# Turla
# - T1110 Brute Force
# - T1192 Spearphishing Link
# - T1012 Query Registry
# - T1086 PowerShell
# - T1007 System Service Discovery
# - T1083 File and Directory Discovery
# - T1060 Registry Run Keys / Startup Folder
# - T1102 Web Service
# - T1055 Process Injection
# - T1204 User Execution
# - T1105 Remote File Copy
# - T1018 Remote System Discovery
# - T1016 System Network Configuration Discovery
# - T1082 System Information Discovery
# - T1004 Winlogon Helper DLL
# - T1071 Standard Application Layer Protocol
# - T1066 Indicator Removal from Tools
# - T1057 Process Discovery
# - T1049 System Network Connections Discovery
# - T1193 Spearphishing Attachment
# - T1077 Windows Admin Shares
# - T1124 System Time Discovery
# - T1504 PowerShell Profile
# - T1112 Modify Registry
# - T1027 Obfuscated Files or Information
# - T1084 Windows Management Instrumentation Event Subscription
# - T1106 Execution through API
# - T1089 Disabling Security Tools
# - T1140 Deobfuscate/Decode Files or Information
# - T1090 Connection Proxy
# - T1025 Data from Removable Media
# - T1134 Access Token Manipulation
# - T1005 Data from Local System
# - T1059 Command-Line Interface
# - T1081 Credentials in Files
# - T1064 Scripting
# - T1048 Exfiltration Over Alternative Protocol
# - T1022 Data Encrypted
# WIRTE
# - T1071 Standard Application Layer Protocol
# - T1064 Scripting
# - T1086 PowerShell
# - T1105 Remote File Copy
# - T1117 Regsvr32
# - T1140 Deobfuscate/Decode Files or Information
# Winnti Group
# - T1014 Rootkit
# - T1116 Code Signing
# - T1057 Process Discovery
# admin@338
# - T1087 Account Discovery
# - T1069 Permission Groups Discovery
# - T1059 Command-Line Interface
# - T1082 System Information Discovery
# - T1036 Masquerading
# - T1083 File and Directory Discovery
# - T1016 System Network Configuration Discovery
# - T1049 System Network Connections Discovery
# - T1007 System Service Discovery
# - T1203 Exploitation for Client Execution
# - T1204 User Execution
# - T1193 Spearphishing Attachment
# menuPass
# - T1047 Windows Management Instrumentation
# - T1003 Credential Dumping
# - T1078 Valid Accounts
# - T1016 System Network Configuration Discovery
# - T1039 Data from Network Shared Drive
# - T1087 Account Discovery
# - T1027 Obfuscated Files or Information
# - T1064 Scripting
# - T1049 System Network Connections Discovery
# - T1204 User Execution
# - T1090 Connection Proxy
# - T1053 Scheduled Task
# - T1199 Trusted Relationship
# - T1059 Command-Line Interface
# - T1038 DLL Search Order Hijacking
# - T1093 Process Hollowing
# - T1140 Deobfuscate/Decode Files or Information
# - T1193 Spearphishing Attachment
# - T1074 Data Staged
# - T1076 Remote Desktop Protocol
# - T1073 DLL Side-Loading
# - T1018 Remote System Discovery
# - T1107 File Deletion
# - T1105 Remote File Copy
# - T1021 Remote Services
# - T1086 PowerShell
# - T1002 Data Compressed
# - T1046 Network Service Scanning
# - T1036 Masquerading
# - T1022 Data Encrypted
# - T1005 Data from Local System
# - T1056 Input Capture

# %%
for actor in attack.actors:
    if actor.name == 'APT28':
        print('Techniques\n====')
        for technique in actor.techniques:
            print('-', technique.id, technique.name)
        print('Tools\n=====')
        for tool in actor.tools:
            print(tool.name, '-', tool.description.replace('\n', ' '))
        print('\nMalware\n=====')
        for malware in actor.malwares:
            print(malware.name, '-', malware.description)
# Out:
# Techniques
# ====
# - T1001 Data Obfuscation
# - T1091 Replication Through Removable Media
# - T1114 Email Collection
# - T1105 Remote File Copy
# - T1173 Dynamic Data Exchange
# - T1158 Hidden Files and Directories
# - T1099 Timestomp
# - T1192 Spearphishing Link
# - T1120 Peripheral Device Discovery
# - T1113 Screen Capture
# - T1083 File and Directory Discovery
# - T1070 Indicator Removal on Host
# - T1204 User Execution
# - T1122 Component Object Model Hijacking
# - T1193 Spearphishing Attachment
# - T1213 Data from Information Repositories
# - T1037 Logon Scripts
# - T1059 Command-Line Interface
# - T1040 Network Sniffing
# - T1067 Bootkit
# - T1068 Exploitation for Privilege Escalation
# - T1211 Exploitation for Defense Evasion
# - T1119 Automated Collection
# - T1134 Access Token Manipulation
# - T1025 Data from Removable Media
# - T1074 Data Staged
# - T1075 Pass the Hash
# - T1078 Valid Accounts
# - T1199 Trusted Relationship
# - T1085 Rundll32
# - T1071 Standard Application Layer Protocol
# - T1086 PowerShell
# - T1092 Communication Through Removable Media
# - T1005 Data from Local System
# - T1003 Credential Dumping
# - T1107 File Deletion
# - T1027 Obfuscated Files or Information
# - T1014 Rootkit
# - T1002 Data Compressed
# - T1064 Scripting
# - T1090 Connection Proxy
# - T1057 Process Discovery
# - T1210 Exploitation of Remote Services
# - T1056 Input Capture
# - T1140 Deobfuscate/Decode Files or Information
# - T1203 Exploitation for Client Execution
# - T1137 Office Application Startup
# - T1221 Template Injection
# - T1024 Custom Cryptographic Protocol
# - T1043 Commonly Used Port
# - T1527 Application Access Token
# - T1528 Steal Application Access Token
# - T1143 Hidden Window
# Tools
# =====
# Mimikatz - [Mimikatz](https://attack.mitre.org/software/S0002) is a credential dumper capable of obtaining plaintext Windows account logins and passwords, along with many other features that make it useful for testing the security of networks. (Citation: Deply Mimikatz) (Citation: Adsecurity Mimikatz Guide)
# Responder - Responder is an open source tool used for LLMNR, NBT-NS and MDNS poisoning, with built-in HTTP/SMB/MSSQL/FTP/LDAP rogue authentication server supporting NTLMv1/NTLMv2/LMv2, Extended Security NTLMSSP and Basic HTTP authentication. (Citation: GitHub Responder)
# certutil - [certutil](https://attack.mitre.org/software/S0160) is a command-line utility that can be used to obtain certificate authority information and configure Certificate Services. (Citation: TechNet Certutil)
# Winexe - [Winexe](https://attack.mitre.org/software/S0191) is a lightweight, open source tool similar to [PsExec](https://attack.mitre.org/software/S0029) designed to allow system administrators to execute commands on remote servers. (Citation: Winexe Github Sept 2013) [Winexe](https://attack.mitre.org/software/S0191) is unique in that it is a GNU/Linux based client. (Citation: Überwachung APT28 Forfiles June 2015)
# Koadic - [Koadic](https://attack.mitre.org/software/S0250) is a Windows post-exploitation framework and penetration testing tool. [Koadic](https://attack.mitre.org/software/S0250) is publicly available on GitHub and the tool is executed via the command-line. [Koadic](https://attack.mitre.org/software/S0250) has several options for staging payloads and creating implants. [Koadic](https://attack.mitre.org/software/S0250) performs most of its operations using Windows Script Host. (Citation: Github Koadic) (Citation: Palo Alto Sofacy 06-2018)
# Forfiles - [Forfiles](https://attack.mitre.org/software/S0193) is a Windows utility commonly used in batch jobs to execute commands on one or more selected files or directories (ex: list all directories in a drive, read the first line of all files created yesterday, etc.). Forfiles can be executed from either the command line, Run window, or batch files/scripts. (Citation: Microsoft Forfiles Aug 2016)
#
# Malware
# =====
# USBStealer - [USBStealer](https://attack.mitre.org/software/S0136) is malware that has used by [APT28](https://attack.mitre.org/groups/G0007) since at least 2005 to extract information from air-gapped networks. It does not have the capability to communicate over the Internet and has been used in conjunction with [ADVSTORESHELL](https://attack.mitre.org/software/S0045). (Citation: ESET Sednit USBStealer 2014) (Citation: Kaspersky Sofacy)
# HIDEDRV - [HIDEDRV](https://attack.mitre.org/software/S0135) is a rootkit used by [APT28](https://attack.mitre.org/groups/G0007). It has been deployed along with [Downdelph](https://attack.mitre.org/software/S0134) to execute and hide that malware. (Citation: ESET Sednit Part 3) (Citation: Sekoia HideDRV Oct 2016)
# JHUHUGIT - [JHUHUGIT](https://attack.mitre.org/software/S0044) is malware used by [APT28](https://attack.mitre.org/groups/G0007). It is based on Carberp source code and serves as reconnaissance malware. (Citation: Kaspersky Sofacy) (Citation: F-Secure Sofacy 2015) (Citation: ESET Sednit Part 1) (Citation: FireEye APT28 January 2017)
# DealersChoice - [DealersChoice](https://attack.mitre.org/software/S0243) is a Flash exploitation framework used by [APT28](https://attack.mitre.org/groups/G0007). (Citation: Sofacy DealersChoice)
# ADVSTORESHELL - [ADVSTORESHELL](https://attack.mitre.org/software/S0045) is a spying backdoor that has been used by [APT28](https://attack.mitre.org/groups/G0007) from at least 2012 to 2016. It is generally used for long-term espionage and is deployed on targets deemed interesting after a reconnaissance phase. (Citation: Kaspersky Sofacy) (Citation: ESET Sednit Part 2)
# OLDBAIT - [OLDBAIT](https://attack.mitre.org/software/S0138) is a credential harvester used by [APT28](https://attack.mitre.org/groups/G0007). (Citation: FireEye APT28) (Citation: FireEye APT28 January 2017)
# XAgentOSX - [XAgentOSX](https://attack.mitre.org/software/S0161) is a trojan that has been used by [APT28](https://attack.mitre.org/groups/G0007)  on OS X and appears to be a port of their standard [CHOPSTICK](https://attack.mitre.org/software/S0023) or XAgent trojan. (Citation: XAgentOSX 2017)
# XTunnel - [XTunnel](https://attack.mitre.org/software/S0117) a VPN-like network proxy tool that can relay traffic between a C2 server and a victim. It was first seen in May 2013 and reportedly used by [APT28](https://attack.mitre.org/groups/G0007) during the compromise of the Democratic National Committee. (Citation: Crowdstrike DNC June 2016) (Citation: Invincea XTunnel) (Citation: ESET Sednit Part 2)
# Zebrocy - [Zebrocy](https://attack.mitre.org/software/S0251) is a Trojan that has been used by [APT28](https://attack.mitre.org/groups/G0007) since at least November 2015. The malware comes in several programming language variants, including C++, Delphi, AutoIt, C#, and VB.NET. (Citation: Palo Alto Sofacy 06-2018)(Citation: Unit42 Cannon Nov 2018)(Citation: Unit42 Sofacy Dec 2018)
# CORESHELL - [CORESHELL](https://attack.mitre.org/software/S0137) is a downloader used by [APT28](https://attack.mitre.org/groups/G0007). The older versions of this malware are known as SOURFACE and newer versions as CORESHELL.(Citation: FireEye APT28) (Citation: FireEye APT28 January 2017)
# Cannon - [Cannon](https://attack.mitre.org/software/S0351) is a Trojan with variants written in C# and Delphi. It was first observed in April 2018. (Citation: Unit42 Cannon Nov 2018)(Citation: Unit42 Sofacy Dec 2018)
# CHOPSTICK - [CHOPSTICK](https://attack.mitre.org/software/S0023) is a malware family of modular backdoors used by [APT28](https://attack.mitre.org/groups/G0007). It has been used since at least 2012 and is usually dropped on victims as second-stage malware, though it has been used as first-stage malware in several cases. It has both Windows and Linux variants. (Citation: FireEye APT28) (Citation: ESET Sednit Part 2) (Citation: FireEye APT28 January 2017) (Citation: DOJ GRU Indictment Jul 2018) It is tracked separately from the [X-Agent for Android](https://attack.mitre.org/software/S0314).
# Komplex - [Komplex](https://attack.mitre.org/software/S0162) is a backdoor that has been used by [APT28](https://attack.mitre.org/groups/G0007) on OS X and appears to be developed in a similar manner to [XAgentOSX](https://attack.mitre.org/software/S0161) (Citation: XAgentOSX 2017) (Citation: Sofacy Komplex Trojan).
# LoJax - [LoJax](https://attack.mitre.org/software/S0397) is a UEFI rootkit used by [APT28](https://attack.mitre.org/groups/G0007) to persist remote access software on targeted systems.(Citation: ESET LoJax Sept 2018)
# Downdelph - [Downdelph](https://attack.mitre.org/software/S0134) is a first-stage downloader written in Delphi that has been used by [APT28](https://attack.mitre.org/groups/G0007) in rare instances between 2013 and 2015. (Citation: ESET Sednit Part 3)
# Fysbis - [Fysbis](https://attack.mitre.org/software/S0410) is a Linux-based backdoor used by [APT28](https://attack.mitre.org/groups/G0007) that dates back to at least 2014.(Citation: Fysbis Palo Alto Analysis)

# %%
from collections import Counter

mitigations_counter = Counter([
    mitigation.name
    for technique in attack.techniques
    for mitigation in technique.mitigations])

# %%
mitigations_counter.most_common()
# Out:
# [('Privileged Account Management', 37),
#  ('User Account Management', 37),
#  ('Execution Prevention', 32),
#  ('Restrict File and Directory Permissions', 29),
#  ('Network Intrusion Prevention', 28),
#  ('Disable or Remove Feature or Program', 24),
#  ('Audit', 23),
#  ('Network Segmentation', 22),
#  ('Operating System Configuration', 18),
#  ('Update Software', 17),
#  ('User Training', 17),
#  ('Password Policies', 17),
#  ('Filter Network Traffic', 15),
#  ('Multi-factor Authentication', 13),
#  ('Code Signing', 10),
#  ('Restrict Web-Based Content', 10),
#  ('Encrypt Sensitive Information', 10),
#  ('Application Isolation and Sandboxing', 10),
#  ('Exploit Protection', 10),
#  ('Software Configuration', 8),
#  ('User Account Control', 6),
#  ('Data Backup', 6),
#  ('Antivirus/Antimalware', 6),
#  ('Limit Access to Resource Over Network', 5),
#  ('Active Directory Configuration', 5),
#  ('Restrict Registry Permissions', 5),
#  ('Remote Data Storage', 4),
#  ('Threat Intelligence Program', 4),
#  ('Privileged Process Integrity', 3),
#  ('Boot Integrity', 3),
#  ('Data Destruction Mitigation', 3),
#  ('Vulnerability Scanning', 3),
#  ('Limit Software Installation', 2),
#  ('Environment Variable Permissions', 2),
#  ('Credential Access Protection', 2),
#  ('Restrict Library Loading', 2),
#  ('SSL/TLS Inspection', 2),
#  ('Behavior Prevention on Endpoint', 2),
#  ('Limit Hardware Installation', 2),
#  ('.bash_profile and .bashrc Mitigation', 1),
#  ('Access Token Manipulation Mitigation', 1),
#  ('Accessibility Features Mitigation', 1),
#  ('Account Discovery Mitigation', 1),
#  ('Account Manipulation Mitigation', 1),
#  ('AppCert DLLs Mitigation', 1),
#  ('AppInit DLLs Mitigation', 1),
#  ('AppleScript Mitigation', 1),
#  ('Application Deployment Software Mitigation', 1),
#  ('Application Shimming Mitigation', 1),
#  ('Application Window Discovery Mitigation', 1),
#  ('Audio Capture Mitigation', 1),
#  ('Authentication Package Mitigation', 1),
#  ('Automated Collection Mitigation', 1),
#  ('Automated Exfiltration Mitigation', 1),
#  ('BITS Jobs Mitigation', 1),
#  ('Bash History Mitigation', 1),
#  ('Binary Padding Mitigation', 1),
#  ('Bootkit Mitigation', 1),
#  ('Browser Bookmark Discovery Mitigation', 1),
#  ('Browser Extensions Mitigation', 1),
#  ('Brute Force Mitigation', 1),
#  ('Account Use Policies', 1),
#  ('Bypass User Account Control Mitigation', 1),
#  ('CMSTP Mitigation', 1),
#  ('Change Default File Association Mitigation', 1),
#  ('Clear Command History Mitigation', 1),
#  ('Clipboard Data Mitigation', 1),
#  ('Code Signing Mitigation', 1),
#  ('Command-Line Interface Mitigation', 1),
#  ('Commonly Used Port Mitigation', 1),
#  ('Communication Through Removable Media Mitigation', 1),
#  ('Compile After Delivery Mitigation', 1),
#  ('Compiled HTML File Mitigation', 1),
#  ('Component Firmware Mitigation', 1),
#  ('Component Object Model Hijacking Mitigation', 1),
#  ('Distributed Component Object Model Mitigation', 1),
#  ('Connection Proxy Mitigation', 1),
#  ('Control Panel Items Mitigation', 1),
#  ('Create Account Mitigation', 1),
#  ('Credential Dumping Mitigation', 1),
#  ('Credentials in Files Mitigation', 1),
#  ('Credentials in Registry Mitigation', 1),
#  ('Custom Command and Control Protocol Mitigation', 1),
#  ('Custom Cryptographic Protocol Mitigation', 1),
#  ('DCShadow Mitigation', 1),
#  ('DLL Search Order Hijacking Mitigation', 1),
#  ('DLL Side-Loading Mitigation', 1),
#  ('Data Compressed Mitigation', 1),
#  ('Data Encoding Mitigation', 1),
#  ('Data Encrypted Mitigation', 1),
#  ('Data Encrypted for Impact Mitigation', 1),
#  ('Data Obfuscation Mitigation', 1),
#  ('Data Staged Mitigation', 1),
#  ('Data Transfer Size Limits Mitigation', 1),
#  ('Data from Information Repositories Mitigation', 1),
#  ('Data from Local System Mitigation', 1),
#  ('Data from Network Shared Drive Mitigation', 1),
#  ('Data from Removable Media Mitigation', 1),
#  ('Defacement Mitigation ', 1),
#  ('Deobfuscate/Decode Files or Information Mitigation', 1),
#  ('Disabling Security Tools Mitigation', 1),
#  ('Domain Fronting Mitigation', 1),
#  ('Domain Generation Algorithms Mitigation', 1),
#  ('Domain Trust Discovery Mitigation', 1),
#  ('Drive-by Compromise Mitigation', 1),
#  ('Dylib Hijacking Mitigation', 1),
#  ('Dynamic Data Exchange Mitigation', 1),
#  ('Email Collection Mitigation', 1),
#  ('Endpoint Denial of Service Mitigation', 1),
#  ('Environmental Keying Mitigation', 1),
#  ('Do Not Mitigate', 1),
#  ('Execution through API Mitigation', 1),
#  ('Execution through Module Load Mitigation', 1),
#  ('Exfiltration Over Alternative Protocol Mitigation', 1),
#  ('Exfiltration Over Command and Control Channel Mitigation', 1),
#  ('Exfiltration Over Other Network Medium Mitigation', 1),
#  ('Exfiltration Over Physical Medium Mitigation', 1),
#  ('Exploit Public-Facing Application Mitigation', 1),
#  ('Exploitation for Client Execution Mitigation', 1),
#  ('Exploitation for Credential Access Mitigation', 1),
#  ('Exploitation for Defense Evasion Mitigation', 1),
#  ('Exploitation for Privilege Escalation Mitigation', 1),
#  ('Exploitation of Remote Services Mitigation', 1),
#  ('External Remote Services Mitigation', 1),
#  ('Extra Window Memory Injection Mitigation', 1),
#  ('Fallback Channels Mitigation', 1),
#  ('File Deletion Mitigation', 1),
#  ('File System Logical Offsets Mitigation', 1),
#  ('File System Permissions Weakness Mitigation', 1),
#  ('File and Directory Discovery Mitigation', 1),
#  ('File Permissions Modification Mitigation', 1),
#  ('Firmware Corruption Mitigation', 1),
#  ('Forced Authentication Mitigation', 1),
#  ('Gatekeeper Bypass Mitigation', 1),
#  ('Graphical User Interface Mitigation', 1),
#  ('Group Policy Modification Mitigation', 1),
#  ('HISTCONTROL Mitigation', 1),
#  ('Hardware Additions Mitigation', 1),
#  ('Hidden Files and Directories Mitigation', 1),
#  ('Hidden Users Mitigation', 1),
#  ('Hidden Window Mitigation', 1),
#  ('Hooking Mitigation', 1),
#  ('Hypervisor Mitigation', 1),
#  ('Image File Execution Options Injection Mitigation', 1),
#  ('Indicator Blocking Mitigation', 1),
#  ('Indicator Removal from Tools Mitigation', 1),
#  ('Indicator Removal on Host Mitigation', 1),
#  ('Indirect Command Execution Mitigation', 1),
#  ('Inhibit System Recovery Mitigation', 1),
#  ('Input Capture Mitigation', 1),
#  ('Input Prompt Mitigation', 1),
#  ('Install Root Certificate Mitigation', 1),
#  ('InstallUtil Mitigation', 1),
#  ('Kerberoasting Mitigation', 1),
#  ('Kernel Modules and Extensions Mitigation', 1),
#  ('Keychain Mitigation', 1),
#  ('LC_LOAD_DYLIB Addition Mitigation', 1),
#  ('LC_MAIN Hijacking Mitigation', 1),
#  ('LLMNR/NBT-NS Poisoning Mitigation', 1),
#  ('LSASS Driver Mitigation', 1),
#  ('Launch Agent Mitigation', 1),
#  ('Launch Daemon Mitigation', 1),
#  ('Launchctl Mitigation', 1),
#  ('Local Job Scheduling Mitigation', 1),
#  ('Login Item Mitigation', 1),
#  ('Logon Scripts Mitigation', 1),
#  ('Man in the Browser Mitigation', 1),
#  ('Masquerading Mitigation', 1),
#  ('Modify Existing Service Mitigation', 1),
#  ('Modify Registry Mitigation', 1),
#  ('Mshta Mitigation', 1),
#  ('Multi-Stage Channels Mitigation', 1),
#  ('Multi-hop Proxy Mitigation', 1),
#  ('Multiband Communication Mitigation', 1),
#  ('Multilayer Encryption Mitigation', 1),
#  ('NTFS File Attributes Mitigation', 1),
#  ('Netsh Helper DLL Mitigation', 1),
#  ('Network Denial of Service Mitigation', 1),
#  ('Network Service Scanning Mitigation', 1),
#  ('Network Share Connection Removal Mitigation', 1),
#  ('Network Share Discovery Mitigation', 1),
#  ('Network Sniffing Mitigation', 1),
#  ('New Service Mitigation', 1),
#  ('Obfuscated Files or Information Mitigation', 1),
#  ('Office Application Startup Mitigation', 1),
#  ('Pass the Hash Mitigation', 1),
#  ('Pass the Ticket Mitigation', 1),
#  ('Password Filter DLL Mitigation', 1),
#  ('Password Policy Discovery Mitigation', 1),
#  ('Path Interception Mitigation', 1),
#  ('Peripheral Device Discovery Mitigation', 1),
#  ('Permission Groups Discovery Mitigation', 1),
#  ('Plist Modification Mitigation', 1),
#  ('Port Knocking Mitigation', 1),
#  ('Port Monitors Mitigation', 1),
#  ('PowerShell Mitigation', 1),
#  ('Private Keys Mitigation', 1),
#  ('Process Discovery Mitigation', 1),
#  ('Process Doppelgänging Mitigation', 1),
#  ('Process Hollowing Mitigation', 1),
#  ('Process Injection Mitigation', 1),
#  ('Query Registry Mitigation', 1),
#  ('Rc.common Mitigation', 1),
#  ('Re-opened Applications Mitigation', 1),
#  ('Redundant Access Mitigation', 1),
#  ('Registry Run Keys / Startup Folder Mitigation', 1),
#  ('Regsvcs/Regasm Mitigation', 1),
#  ('Regsvr32 Mitigation', 1),
#  ('Remote Access Tools Mitigation', 1),
#  ('Remote Desktop Protocol Mitigation', 1),
#  ('Remote File Copy Mitigation', 1),
#  ('Remote Services Mitigation', 1),
#  ('Remote System Discovery Mitigation', 1),
#  ('Replication Through Removable Media Mitigation', 1),
#  ('Resource Hijacking Mitigation', 1),
#  ('Rootkit Mitigation', 1),
#  ('Rundll32 Mitigation', 1),
#  ('Runtime Data Manipulation Mitigation', 1),
#  ('SID-History Injection Mitigation', 1),
#  ('SIP and Trust Provider Hijacking Mitigation', 1),
#  ('SSH Hijacking Mitigation', 1),
#  ('Scheduled Task Mitigation', 1),
#  ('Scheduled Transfer Mitigation', 1),
#  ('Screen Capture Mitigation', 1),
#  ('Screensaver Mitigation', 1),
#  ('Scripting Mitigation', 1),
#  ('Security Software Discovery Mitigation', 1),
#  ('Security Support Provider Mitigation', 1),
#  ('Service Execution Mitigation', 1),
#  ('Service Registry Permissions Weakness Mitigation', 1),
#  ('Service Stop Mitigation', 1),
#  ('Setuid and Setgid Mitigation', 1),
#  ('Shared Webroot Mitigation', 1),
#  ('Shortcut Modification Mitigation', 1),
#  ('Signed Binary Proxy Execution Mitigation', 1),
#  ('Signed Script Proxy Execution Mitigation', 1),
#  ('Software Packing Mitigation', 1),
#  ('Source Mitigation', 1),
#  ('Space after Filename Mitigation', 1),
#  ('Spearphishing Attachment Mitigation', 1),
#  ('Spearphishing Link Mitigation', 1),
#  ('Spearphishing via Service Mitigation', 1),
#  ('Standard Application Layer Protocol Mitigation', 1),
#  ('Standard Cryptographic Protocol Mitigation', 1),
#  ('Standard Non-Application Layer Protocol Mitigation', 1),
#  ('Startup Items Mitigation', 1),
#  ('Stored Data Manipulation Mitigation', 1),
#  ('Sudo Mitigation', 1),
#  ('Sudo Caching Mitigation', 1),
#  ('Supply Chain Compromise Mitigation', 1),
#  ('System Firmware Mitigation', 1),
#  ('System Information Discovery Mitigation', 1),
#  ('System Network Configuration Discovery Mitigation', 1),
#  ('System Network Connections Discovery Mitigation', 1),
#  ('System Owner/User Discovery Mitigation', 1),
#  ('System Service Discovery Mitigation', 1),
#  ('System Time Discovery Mitigation', 1),
#  ('Systemd Service Mitigation', 1),
#  ('Taint Shared Content Mitigation', 1),
#  ('Template Injection Mitigation', 1),
#  ('Third-party Software Mitigation', 1),
#  ('Time Providers Mitigation', 1),
#  ('Timestomp Mitigation', 1),
#  ('Transmitted Data Manipulation Mitigation', 1),
#  ('Trap Mitigation', 1),
#  ('Trusted Developer Utilities Mitigation', 1),
#  ('Trusted Relationship Mitigation', 1),
#  ('Two-Factor Authentication Interception Mitigation', 1),
#  ('Uncommonly Used Port Mitigation', 1),
#  ('User Execution Mitigation', 1),
#  ('Valid Accounts Mitigation', 1),
#  ('Application Developer Guidance', 1),
#  ('Video Capture Mitigation', 1),
#  ('Virtualization/Sandbox Evasion Mitigation', 1),
#  ('Web Service Mitigation', 1),
#  ('Web Shell Mitigation', 1),
#  ('Windows Admin Shares Mitigation', 1),
#  ('Windows Management Instrumentation Mitigation', 1),
#  ('Windows Management Instrumentation Event Subscription Mitigation', 1),
#  ('Windows Remote Management Mitigation', 1),
#  ('Winlogon Helper DLL Mitigation', 1),
#  ('XSL Script Processing Mitigation', 1)]

# %% [markdown]
# <hr>
#
# # Part 2 - Generate Coverage Spreadsheet
#
# Placeholder descriptive text

# %% [markdown]
# ## Group Techniques by Data Source

# %%
from collections import defaultdict

def group_techniques_by_data_source(attack, actor_name=None):
    data_sources = defaultdict(list)
    for technique in attack.techniques:
        if actor_name:
            related_actors = [actor.name for actor in technique.actors]
            if actor_name not in related_actors:
                continue
        if technique.data_source:
            for data_source in technique.data_source:
                data_sources[data_source].append(technique.id)
    return data_sources

# %%
data_source_map = group_techniques_by_data_source(attack)

# %%
data_source_map.keys()
# Out:
# dict_keys(['File monitoring', 'Process monitoring', 'Process command-line parameters', 'Process use of network', 'API monitoring', 'Access tokens', 'Windows Registry', 'Windows event logs', 'Azure activity logs', 'Office 365 account logs', 'Authentication logs', 'Packet capture', 'Loaded DLLs', 'System calls', 'OAuth audit logs', 'DLL monitoring', 'Data loss prevention', 'Binary file metadata', 'Malware reverse engineering', 'MBR', 'VBR', 'Network protocol analysis', 'Browser extensions', 'AWS CloudTrail logs', 'Office 365 audit logs', 'Stackdriver logs', 'Netflow/Enclave netflow', 'Disk forensics', 'Component firmware', 'PowerShell logs', 'Host network interface', 'Network intrusion detection system', 'Kernel drivers', 'Application logs', 'Third-party application logs', 'Web application firewall logs', 'Web logs', 'Services', 'Anti-virus', 'SSL/TLS inspection', 'Network device logs', 'DNS records', 'Web proxy', 'Office 365 trace logs', 'Mail server', 'Email gateway', 'User interface', 'Windows Error Reporting', 'BIOS', 'Environment variable', 'Asset management', 'Sensor health and status', 'Digital certificate logs', 'Named Pipes', 'Azure OS logs', 'AWS OS logs', 'Detonation chamber', 'EFI', 'WMI Objects'])

# %%
data_source_map['Authentication logs']
# Out:
# ['T1098',
#  'T1110',
#  'T1088',
#  'T1146',
#  'T1522',
#  'T1175',
#  'T1136',
#  'T1207',
#  'T1213',
#  'T1114',
#  'T1212',
#  'T1133',
#  'T1148',
#  'T1147',
#  'T1185',
#  'T1126',
#  'T1075',
#  'T1097',
#  'T1108',
#  'T1076',
#  'T1021',
#  'T1178',
#  'T1184',
#  'T1199',
#  'T1078',
#  'T1506',
#  'T1100',
#  'T1077',
#  'T1047',
#  'T1028']

# %%
apt1_data_source_map = group_techniques_by_data_source(attack, actor_name='APT1')
apt1_data_source_map.keys()
# Out:
# dict_keys(['Azure activity logs', 'Office 365 account logs', 'API monitoring', 'Process monitoring', 'Process command-line parameters', 'File monitoring', 'Data loss prevention', 'PowerShell logs', 'Binary file metadata', 'Office 365 trace logs', 'Mail server', 'Email gateway', 'Authentication logs', 'Process use of network', 'Network protocol analysis', 'Netflow/Enclave netflow'])

# %%
apt1_data_source_map['Authentication logs']
# Out:
# ['T1114', 'T1075', 'T1076']

# %% [markdown]
# ## Generate the spreadsheet

# %%
import pandas as pd

def create_data_source_spreadsheet(data_source_map, fp='Data Source Coverage Spreadsheet.xlsx'):
    (pd.DataFrame([
        {'Data Source': data_source, 'Techniques': techniques}
         for data_source, techniques in data_source_map.items()])
     .assign(**{'Num of Techniques': lambda df: df.Techniques.str.len(),
                'Data Source Available?': '',
                'Comments': ''})
     .drop(columns=['Techniques'])
     .set_index('Data Source')
     .sort_index()
     .to_excel(fp))
    
    print(f'Wrote data source coverage spreadsheet to {fp}')

# %%
create_data_source_spreadsheet(data_source_map)
# Out:
# Wrote data source coverage spreadsheet to Data Source Coverage Spreadsheet.xlsx

# %%
create_data_source_spreadsheet(apt1_data_source_map, fp='APT1 Data Source Coverage Spreadsheet.xlsx')
# Out:
# Wrote data source coverage spreadsheet to APT1 Data Source Coverage Spreadsheet.xlsx

# %% [markdown]
# <hr>
#
# # Part 3 - Generate Layer File
#
# > ref: https://github.com/mitre-attack/attack-navigator/blob/master/layers/LAYERFORMATv2_2.md

# %%
from pathlib import Path
from collections import defaultdict
import json


class NavigatorLayer(object):
    def __init__(self, version='2.2', name='Default Layer Name',
                 description='Default Description', domain='mitre-enterprise',
                 colors=['#ffffff', '#b3d9ff'], min_value=0, max_value=100,
                 sorting=0, view_mode=0, hide_disabled=False, stages=['act'], metadata=None,
                 platforms=['Windows', 'SaaS', 'Azure AD', 'Azure', 'GCP',
                            'Office 365', 'AWS', 'macOS', 'Linux']):
        self.content = {
            'name': name,
            'version': version,
            'domain': domain,
            'description': description,
            'filters': {
                'stages': stages,
                'platforms': platforms
            },
            'gradient': {
                'colors': colors,
                'maxValue': max_value,
                'minValue': min_value
            },
            'sorting': sorting,
            'viewMode': view_mode,
            'hideDisabled': hide_disabled,
            'metadata': [],
            'techniques': []}

        if metadata:
            self.content['metadata'].extend(metadata)

    def to_json(self, fp):
        data = json.dumps(self.content, indent=4)
        Path(fp).write_text(data)

# %%
import pandas as pd


def populate_layer_from_spreadsheet(attack, actor_name=None, 
                                    spreadsheet_fp='Data Source Coverage Spreadsheet.xlsx'):
    layer_content = []
    spreadsheet = pd.read_excel(spreadsheet_fp)
    available_data_sources = spreadsheet[
        spreadsheet['Data Source Available?'].str.lower() == 'yes']

    covered_techniques = defaultdict(list)
    for technique in attack.techniques:
        
        if actor_name:
            related_actors = [actor.name for actor in technique.actors]
            if actor_name not in related_actors:
                layer_content.append({
                    'techniqueID': technique.id,
                    'enabled': False})
                continue
            
        for data_source in available_data_sources['Data Source'].unique():
            if technique.data_source and data_source in technique.data_source:
                covered_techniques[technique.id].append(data_source)

    for technique in covered_techniques:
        layer_content.append({
            'techniqueID': technique,
            'score': len(covered_techniques[technique]),
            'metadata': [{
                'name': 'Data Sources',
                'value': ', '.join(covered_techniques[technique])}]})

    return layer_content

# %%
layer = NavigatorLayer(
    name='Data Source Coverage Map',
    description='Shows techniques where the organization has a relevant data source',
    max_value=1)

# %%
layer.content['techniques'] = populate_layer_from_spreadsheet(
    attack, spreadsheet_fp='Data Source Coverage Spreadsheet.xlsx')

# %%
layer.content
# Out:
# {'name': 'Data Source Coverage Map',
#  'version': '2.2',
#  'domain': 'mitre-enterprise',
#  'description': 'Shows techniques where the organization has a relevant data source',
#  'filters': {'stages': ['act'],
#   'platforms': ['Windows',
#    'SaaS',
#    'Azure AD',
#    'Azure',
#    'GCP',
#    'Office 365',
#    'AWS',
#    'macOS',
#    'Linux']},
#  'gradient': {'colors': ['#ffffff', '#b3d9ff'], 'maxValue': 1, 'minValue': 0},
#  'sorting': 0,
#  'viewMode': 0,
#  'hideDisabled': False,
#  'metadata': [],
#  'techniques': [{'techniqueID': 'T1134',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1531',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1087',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1098',
#    'score': 3,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Packet capture, Windows event logs'}]},
#   {'techniqueID': 'T1155',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1010',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1123',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1197',
#    'score': 3,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Packet capture, Windows event logs'}]},
#   {'techniqueID': 'T1067',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1217',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1176',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1191',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1115',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1043',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1109',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1175',
#    'score': 3,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Packet capture, Windows event logs'}]},
#   {'techniqueID': 'T1090',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1196',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Windows event logs'}]},
#   {'techniqueID': 'T1136',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1003',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1503',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1094',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1024',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1207',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Packet capture'}]},
#   {'techniqueID': 'T1132',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1001',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1030',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1491',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1089',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1172',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'Packet capture, SSL/TLS inspection'}]},
#   {'techniqueID': 'T1483',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1482',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1189',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'Packet capture, SSL/TLS inspection'}]},
#   {'techniqueID': 'T1173',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Windows event logs'}]},
#   {'techniqueID': 'T1514',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1519',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1499',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'SSL/TLS inspection'}]},
#   {'techniqueID': 'T1106',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1129',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1048',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1190',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1181',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1008',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1006',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1222',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1484',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1143',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1179',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Windows event logs'}]},
#   {'techniqueID': 'T1183',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1070',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Windows event logs'}]},
#   {'techniqueID': 'T1202',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1490',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1056',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1130',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'SSL/TLS inspection'}]},
#   {'techniqueID': 'T1534',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'SSL/TLS inspection'}]},
#   {'techniqueID': 'T1208',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1171',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'Packet capture, Windows event logs'}]},
#   {'techniqueID': 'T1177',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1162',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1185',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Packet capture'}]},
#   {'techniqueID': 'T1112',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1104',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1026',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1079',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1096',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1046',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1126',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1050',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1027',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'SSL/TLS inspection, Windows event logs'}]},
#   {'techniqueID': 'T1502',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Windows event logs'}]},
#   {'techniqueID': 'T1120',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1069',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1205',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1013',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1186',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1093',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1055',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1108',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1105',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1178',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Windows event logs'}]},
#   {'techniqueID': 'T1198',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'API monitoring, Windows event logs'}]},
#   {'techniqueID': 'T1053',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1113',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1489',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1193',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1192',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'Packet capture, SSL/TLS inspection'}]},
#   {'techniqueID': 'T1194',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'SSL/TLS inspection'}]},
#   {'techniqueID': 'T1071',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1032',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'Packet capture, SSL/TLS inspection'}]},
#   {'techniqueID': 'T1095',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1539',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1019',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1529',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Windows event logs'}]},
#   {'techniqueID': 'T1124',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1209',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1493',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'Packet capture'}]},
#   {'techniqueID': 'T1111',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1125',
#    'score': 1,
#    'metadata': [{'name': 'Data Sources', 'value': 'API monitoring'}]},
#   {'techniqueID': 'T1102',
#    'score': 2,
#    'metadata': [{'name': 'Data Sources',
#      'value': 'Packet capture, SSL/TLS inspection'}]}]}

# %%
layer.to_json('data_source_layer.json')

# %%
apt1_layer = NavigatorLayer(
    name='APT1 Data Source Coverage Map',
    description='Shows techniques where the organization has a relevant data source to detect APT1',
    hide_disabled=True,
    max_value=1)

apt1_layer.content['techniques'] = populate_layer_from_spreadsheet(
    attack, actor_name='APT1', spreadsheet_fp='APT1 Data Source Coverage Spreadsheet.xlsx')

apt1_layer.to_json('APT1_layer.json')
